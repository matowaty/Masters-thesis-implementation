# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas_ta_classic deap
# Out:
# Collecting pandas_ta_classic
#   Downloading pandas_ta_classic-0.6.20-py3-none-any.whl.metadata (17 kB)
# Collecting deap
#   Downloading deap-1.4.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas_ta_classic) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas_ta_classic) (2.2.2)
# Collecting moocore (from deap)
#   Downloading moocore-0.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pandas_ta_classic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pandas_ta_classic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pandas_ta_classic) (2026.2)
# Requirement already satisfied: cffi>=1.17.1 in /usr/local/lib/python3.12/dist-packages (from moocore->deap) (2.0.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from moocore->deap) (4.10.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.17.1->moocore->deap) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pandas_ta_classic) (1.17.0)
# Downloading pandas_ta_classic-0.6.20-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.0/396.0 kB 9.4 MB/s eta 0:00:00:00:01
# Downloading deap-1.4.4-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.3 MB/s eta 0:00:00
# Downloading moocore-0.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.9/866.9 kB 38.5 MB/s eta 0:00:00
# Installing collected packages: moocore, pandas_ta_classic, deap
# Successfully installed deap-1.4.4 moocore-0.3.1 pandas_ta_classic-0.6.20

# %%
# %cd /content/drive/MyDrive/Masters-Thesis/
# !python main.py attention_v2_multi
# Out:
# /content/drive/MyDrive/Masters-Thesis
# 2026-06-16 16:34:51,320  INFO      __main__ -- ============================================================
# 2026-06-16 16:34:51,321  INFO      __main__ -- V2 MULTI-STOCK ATTENTION COMPARISON
# 2026-06-16 16:34:51,321  INFO      __main__ -- ============================================================
# 2026-06-16 16:34:51,476  INFO      model_builder -- Auto-detected PyTorch device: cuda
# /content/drive/MyDrive/Masters-Thesis/data_processor_v2.py:84: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns_df = close_df.pct_change()
# 2026-06-16 16:35:00,739  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:00,779  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:00,825  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 2498 NaN warm-up rows
# 2026-06-16 16:35:00,866  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:00,906  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:00,947  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:00,987  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,026  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,066  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,106  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,146  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,186  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,226  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,266  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,305  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,345  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,385  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,426  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,465  INFO      feature_engineer_v2 -- Added all V2 features -- 27 indicator columns, dropped 33 NaN warm-up rows
# 2026-06-16 16:35:01,866  INFO      __main__ -- ----------------------------------------
# 2026-06-16 16:35:01,867  INFO      __main__ -- Training model: bilstm_v2
# 2026-06-16 16:35:01,867  INFO      __main__ -- ----------------------------------------
# 2026-06-16 16:35:01,872  INFO      result_logger -- ResultLogger created run folder: RESULTS/attention_bilstm_v2_multi_all_stocks_20260616_163501
# 2026-06-16 16:35:01,876  INFO      result_logger -- Config saved to RESULTS/attention_bilstm_v2_multi_all_stocks_20260616_163501/config.json
# 2026-06-16 16:35:07,250  INFO      trainer_v2 -- Computed class weights: [1.7453414  0.54649859 1.674438  ] (counts: [ 9588 30621  9994])
# 2026-06-16 16:35:07,261  INFO      __main__ -- Training V2 classification model: bilstm_v2
# 2026-06-16 16:35:07,262  INFO      trainer_v2 -- Starting V2 training on cuda for up to 50 epochs
# 2026-06-16 16:35:12,058  INFO      trainer_v2 -- Epoch   1/50 -- train_loss=1.0649  val_loss=1.0636  [4.8s/epoch, ETA 3m55s]
# 2026-06-16 16:35:15,935  INFO      trainer_v2 -- Epoch   2/50 -- train_loss=1.0414  val_loss=1.0528  [3.9s/epoch, ETA 3m27s]
# 2026-06-16 16:35:19,796  INFO      trainer_v2 -- Epoch   3/50 -- train_loss=1.0291  val_loss=1.0535  [3.9s/epoch, ETA 3m16s]
# 2026-06-16 16:35:23,716  INFO      trainer_v2 -- Epoch   4/50 -- train_loss=1.0216  val_loss=1.0700  [3.9s/epoch, ETA 3m09s]
# 2026-06-16 16:35:27,580  INFO      trainer_v2 -- Epoch   5/50 -- train_loss=1.0147  val_loss=1.0568  [3.9s/epoch, ETA 3m02s]
# 2026-06-16 16:35:31,446  INFO      trainer_v2 -- Epoch   6/50 -- train_loss=1.0080  val_loss=1.0514  [3.9s/epoch, ETA 2m57s]
# 2026-06-16 16:35:35,310  INFO      trainer_v2 -- Epoch   7/50 -- train_loss=1.0007  val_loss=1.0582  [3.9s/epoch, ETA 2m52s]
# 2026-06-16 16:35:39,170  INFO      trainer_v2 -- Epoch   8/50 -- train_loss=0.9948  val_loss=1.0777  [3.9s/epoch, ETA 2m47s]
# 2026-06-16 16:35:43,009  INFO      trainer_v2 -- Epoch   9/50 -- train_loss=0.9869  val_loss=1.0747  [3.8s/epoch, ETA 2m42s]
# 2026-06-16 16:35:46,857  INFO      trainer_v2 -- Epoch  10/50 -- train_loss=0.9791  val_loss=1.1012  [3.8s/epoch, ETA 2m38s]
# 2026-06-16 16:35:50,683  INFO      trainer_v2 -- Epoch  11/50 -- train_loss=0.9709  val_loss=1.0962  [3.8s/epoch, ETA 2m33s]
# 2026-06-16 16:35:54,527  INFO      trainer_v2 -- Epoch  12/50 -- train_loss=0.9626  val_loss=1.1186  [3.8s/epoch, ETA 2m29s]
# 2026-06-16 16:35:58,379  INFO      trainer_v2 -- Epoch  13/50 -- train_loss=0.9523  val_loss=1.1083  [3.8s/epoch, ETA 2m25s]
# 2026-06-16 16:36:02,229  INFO      trainer_v2 -- Epoch  14/50 -- train_loss=0.9418  val_loss=1.1302  [3.8s/epoch, ETA 2m21s]
# 2026-06-16 16:36:06,079  INFO      trainer_v2 -- Epoch  15/50 -- train_loss=0.9299  val_loss=1.1608  [3.8s/epoch, ETA 2m17s]
# 2026-06-16 16:36:09,925  INFO      trainer_v2 -- Epoch  16/50 -- train_loss=0.9215  val_loss=1.1875  [3.8s/epoch, ETA 2m13s]
# 2026-06-16 16:36:09,927  INFO      trainer_v2 -- Early stopping triggered after 10 epochs without improvement
# 2026-06-16 16:36:09,928  INFO      __main__ -- Training Model 2 (Confidence Meta-Model) for bilstm_v2...
# 2026-06-16 16:36:09,928  INFO      confidence_model -- Extracting Calibration features for Model 2...
# 2026-06-16 16:36:10,275  INFO      confidence_model -- Training Model 2 (Gradient Boosting Classifier)...
# 2026-06-16 16:37:29,505  INFO      confidence_model -- Model 2 Calibration Precision (at 0.5 threshold): 0.771
# 2026-06-16 16:37:29,506  INFO      result_viewer_v2 -- ============================================================
# 2026-06-16 16:37:29,506  INFO      result_viewer_v2 -- V2 Pipeline Evaluation on Test Set
# 2026-06-16 16:37:29,506  INFO      result_viewer_v2 -- ============================================================
# 2026-06-16 16:37:29,890  INFO      result_viewer_v2 -- Model 2 Standalone Precision (at 0.5): 75.1%
# 2026-06-16 16:37:29,929  INFO      result_viewer_v2 -- Confidence Threshold: 0.70
# 2026-06-16 16:37:29,929  INFO      result_viewer_v2 -- Trade Approval Rate: 22.6%
# 2026-06-16 16:37:29,929  INFO      result_viewer_v2 -- Precision @ High Confidence: 80.5%
# 2026-06-16 16:37:30,237  INFO      result_viewer_v2 -- Simulated Annualized Sharpe Ratio: -0.33
# 2026-06-16 16:37:30,237  INFO      result_viewer_v2 -- ============================================================
# 2026-06-16 16:37:30,243  INFO      result_logger -- Metrics saved to RESULTS/attention_bilstm_v2_multi_all_stocks_20260616_163501/metrics.json
# 2026-06-16 16:37:30,264  INFO      trainer_v2 -- [OK] V2 Checkpoint saved to checkpoints/attention_bilstm_v2_multi.pt
# 2026-06-16 16:37:30,284  INFO      result_logger -- Checkpoint copied to RESULTS/attention_bilstm_v2_multi_all_stocks_20260616_163501/model.pt
# 2026-06-16 16:37:30,285  INFO      __main__ -- V2 Attention comparison for bilstm_v2 complete. Results saved to /content/drive/MyDrive/Masters-Thesis/RESULTS/attention_bilstm_v2_multi_all_stocks_20260616_163501
#
# [READY TO COPY] python result_viewer.py /content/drive/MyDrive/Masters-Thesis/RESULTS/attention_bilstm_v2_multi_all_stocks_20260616_163501
#
# 2026-06-16 16:37:30,285  INFO      __main__ -- ----------------------------------------
# 2026-06-16 16:37:30,285  INFO      __main__ -- Training model: bilstm_attn_v2
# 2026-06-16 16:37:30,285  INFO      __main__ -- ----------------------------------------
# 2026-06-16 16:37:30,288  INFO      result_logger -- ResultLogger created run folder: RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730
# 2026-06-16 16:37:30,292  INFO      result_logger -- Config saved to RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730/config.json
# 2026-06-16 16:37:30,297  INFO      trainer_v2 -- Computed class weights: [1.7453414  0.54649859 1.674438  ] (counts: [ 9588 30621  9994])
# 2026-06-16 16:37:30,317  INFO      __main__ -- Training V2 classification model: bilstm_attn_v2
# 2026-06-16 16:37:30,318  INFO      trainer_v2 -- Starting V2 training on cuda for up to 50 epochs
# 2026-06-16 16:37:34,565  INFO      trainer_v2 -- Epoch   1/50 -- train_loss=1.0633  val_loss=1.0717  [4.2s/epoch, ETA 3m28s]
# 2026-06-16 16:37:38,861  INFO      trainer_v2 -- Epoch   2/50 -- train_loss=1.0456  val_loss=1.0635  [4.3s/epoch, ETA 3m24s]
# 2026-06-16 16:37:43,103  INFO      trainer_v2 -- Epoch   3/50 -- train_loss=1.0348  val_loss=1.0687  [4.2s/epoch, ETA 3m20s]
# 2026-06-16 16:37:47,341  INFO      trainer_v2 -- Epoch   4/50 -- train_loss=1.0268  val_loss=1.0632  [4.2s/epoch, ETA 3m15s]
# 2026-06-16 16:37:51,598  INFO      trainer_v2 -- Epoch   5/50 -- train_loss=1.0195  val_loss=1.0607  [4.3s/epoch, ETA 3m11s]
# 2026-06-16 16:37:55,796  INFO      trainer_v2 -- Epoch   6/50 -- train_loss=1.0115  val_loss=1.0868  [4.2s/epoch, ETA 3m06s]
# 2026-06-16 16:37:59,990  INFO      trainer_v2 -- Epoch   7/50 -- train_loss=1.0028  val_loss=1.0602  [4.2s/epoch, ETA 3m02s]
# 2026-06-16 16:38:04,213  INFO      trainer_v2 -- Epoch   8/50 -- train_loss=0.9946  val_loss=1.0786  [4.2s/epoch, ETA 2m57s]
# 2026-06-16 16:38:08,395  INFO      trainer_v2 -- Epoch   9/50 -- train_loss=0.9867  val_loss=1.0911  [4.2s/epoch, ETA 2m53s]
# 2026-06-16 16:38:12,591  INFO      trainer_v2 -- Epoch  10/50 -- train_loss=0.9790  val_loss=1.0906  [4.2s/epoch, ETA 2m48s]
# 2026-06-16 16:38:16,847  INFO      trainer_v2 -- Epoch  11/50 -- train_loss=0.9691  val_loss=1.1202  [4.3s/epoch, ETA 2m44s]
# 2026-06-16 16:38:21,054  INFO      trainer_v2 -- Epoch  12/50 -- train_loss=0.9592  val_loss=1.1439  [4.2s/epoch, ETA 2m40s]
# 2026-06-16 16:38:25,295  INFO      trainer_v2 -- Epoch  13/50 -- train_loss=0.9498  val_loss=1.1405  [4.2s/epoch, ETA 2m36s]
# 2026-06-16 16:38:29,561  INFO      trainer_v2 -- Epoch  14/50 -- train_loss=0.9380  val_loss=1.1674  [4.3s/epoch, ETA 2m32s]
# 2026-06-16 16:38:33,763  INFO      trainer_v2 -- Epoch  15/50 -- train_loss=0.9277  val_loss=1.1849  [4.2s/epoch, ETA 2m27s]
# 2026-06-16 16:38:37,988  INFO      trainer_v2 -- Epoch  16/50 -- train_loss=0.9176  val_loss=1.2366  [4.2s/epoch, ETA 2m23s]
# 2026-06-16 16:38:42,236  INFO      trainer_v2 -- Epoch  17/50 -- train_loss=0.9032  val_loss=1.2628  [4.2s/epoch, ETA 2m19s]
# 2026-06-16 16:38:42,238  INFO      trainer_v2 -- Early stopping triggered after 10 epochs without improvement
# 2026-06-16 16:38:42,239  INFO      __main__ -- Training Model 2 (Confidence Meta-Model) for bilstm_attn_v2...
# 2026-06-16 16:38:42,239  INFO      confidence_model -- Extracting Calibration features for Model 2...
# 2026-06-16 16:38:42,616  INFO      confidence_model -- Training Model 2 (Gradient Boosting Classifier)...
# 2026-06-16 16:40:02,900  INFO      confidence_model -- Model 2 Calibration Precision (at 0.5 threshold): 0.764
# 2026-06-16 16:40:02,900  INFO      result_viewer_v2 -- ============================================================
# 2026-06-16 16:40:02,900  INFO      result_viewer_v2 -- V2 Pipeline Evaluation on Test Set
# 2026-06-16 16:40:02,900  INFO      result_viewer_v2 -- ============================================================
# 2026-06-16 16:40:03,326  INFO      result_viewer_v2 -- Model 2 Standalone Precision (at 0.5): 72.8%
# 2026-06-16 16:40:03,366  INFO      result_viewer_v2 -- Confidence Threshold: 0.70
# 2026-06-16 16:40:03,366  INFO      result_viewer_v2 -- Trade Approval Rate: 25.8%
# 2026-06-16 16:40:03,366  INFO      result_viewer_v2 -- Precision @ High Confidence: 79.8%
# 2026-06-16 16:40:03,716  INFO      result_viewer_v2 -- Simulated Annualized Sharpe Ratio: 1.05
# 2026-06-16 16:40:03,716  INFO      result_viewer_v2 -- ============================================================
# 2026-06-16 16:40:03,731  INFO      result_logger -- Metrics saved to RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730/metrics.json
# 2026-06-16 16:40:03,750  INFO      trainer_v2 -- [OK] V2 Checkpoint saved to checkpoints/attention_bilstm_attn_v2_multi.pt
# 2026-06-16 16:40:03,765  INFO      result_logger -- Checkpoint copied to RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730/model.pt
# 2026-06-16 16:40:03,766  INFO      __main__ -- V2 Attention comparison for bilstm_attn_v2 complete. Results saved to /content/drive/MyDrive/Masters-Thesis/RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730
#
# [READY TO COPY] python result_viewer.py /content/drive/MyDrive/Masters-Thesis/RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730

# %%
# %cd /content/drive/MyDrive/Masters-Thesis/
# !python result_viewer.py RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730
# Out:
# /content/drive/MyDrive/Masters-Thesis
#
# ############################################################
#   Results Viewer: attention_bilstm_attn_v2_multi_all_stocks_20260616_163730
# ############################################################
#
# ==================================================
#   Experiment Configuration
# ==================================================
#   data_dir        DATA
#   model           bilstm_attn_v2
#   window_size     12
#   batch_size      64
#   epochs          50
#   learning_rate   0.001000
#   hidden_size     64
#   num_layers      2
#   dropout         0.200000
#   scaling         per-stock
#   mode            v2_multi_classification
# ==================================================
#
#
# ==================================================
#   Test Metrics
# ==================================================
#   m2_precision_at_0.5   72.8%
#   trade_rate            25.8%
#   precision_at_conf     79.8%
#   annualized_sharpe     +1.05
# ==================================================
#
# [SKIP] No best_chromosome.json found (not a GA run).
# [OK] Training curves saved to RESULTS/attention_bilstm_attn_v2_multi_all_stocks_20260616_163730/training_curves.png
# Figure(1000x500)
# [SKIP] No ga_history.csv found (not a GA run).
